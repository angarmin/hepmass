# %% [markdown]
# **Libraries**

# %%
import pandas as pd
import numpy as np

import warnings

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
import joypy #el de las densidades guays

from sklearn import manifold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC  


from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import os 
#cwd = os.getcwd()
cwd="/home/angela/Notebook/machine_learning/normalizados/RF_class_weight/"


from sklearn import metrics


warnings.filterwarnings('ignore') #ATENCION QUE ESTO CREO QUE FUNCIONA PARA TODO EL NOTEBOOK

# %% [markdown]
# **LOAD**

# %%
#ALL THE DATASET

#df=pd.read_pickle("/home/angela/Notebook/data/normalizados/trainpickle")
#df_originaltest=pd.read_pickle("/home/angela/Notebook/data/normalizados/testpickle")

# %%
#SIMPLe DATASET
df=pd.read_pickle("/home/angela/Notebook/data/normalizados/trainsimplepickle")#.sample(n=1000, random_state=1)
df_originaltest=pd.read_pickle("/home/angela/Notebook/data/normalizados/testsimplepickle")#.sample(n=500, random_state=1)

# %% [markdown]
# # Machine learning

# %% [markdown]
# **We will follow the scikit-learn schema to train and validate the model**
#
#
# https://scikit-learn.org/stable/modules/cross_validation.html

# %% [markdown]
# ## RF

# %%
#Scores


def Scores(y_true,y_pred):
    
    tn, fp, fn, tp = metrics.confusion_matrix(y_true, y_pred).ravel()
    spec = tn / (tn+fp)
    sens=tp/(tp+fn)
    acc=metrics.accuracy_score(y_true,y_pred)
    kappa_cohen=metrics.cohen_kappa_score(y_true,y_pred)
        
    return(sens,spec,acc,kappa_cohen,tn, fp, fn, tp)


def model(X_train,y_train,X_test,state, class_weight={0: 1, 1: 1}):

#Choosing the model: 
    
    if state == 1:   #RANDOMFOREST
        params = {'n_estimators':[10,50,100,350],'max_features':['log2','auto','sqrt'],'criterion':['gini','entropy']}
        model = RandomForestClassifier(class_weight=class_weight)
        
    elif state == 2:  #LOGISTIC REGRESSION
        model = LogisticRegression()
        params = {"C": [0.01,0.1,1,10]}  #Regularization, default=1
        
    elif state == 3:   #SVM
        params = {'C':[0.1,1,10],'kernel':['rbf','linear']}  #SVM
        model = SVC(probability=True) 
        #Important, SVC does not work with a big training set, it would be useful to obtain the support vectors
        #in order to select specific samples for working with the whole dataset. 
        
        
    grid = GridSearchCV(estimator=model, 
                           param_grid=params,
                           cv=5,
                           verbose=1)

    grid.fit(X_train,y_train)
    best_model = grid.best_estimator_

    # Predict test set labels
    y_pred = best_model.predict(X_test)    
    y_pred_proba = best_model.predict_proba(X_test)[::,1] #Neccesary to make the ROC curve 
    
    return(grid, best_model,y_pred,y_pred_proba)

# %%
#Metric df: 

weights=[1,10,33,50,66,90,99]

for weight in weights:
    W={0: 1, 1: 100-weight}
    print(W)
    df_metrics = pd.DataFrame(index=[500,750,1000,1250,1500], columns=['accuracy','sensitibity','specifity','kappa','auc'])

    for i in (500,750,1000,1250,1500):

        print('mass=', i )

        #train
        dfmass1000=df.loc[df['mass'] == i]                                                   #to separate the masses. 
        dfmass0=df.loc[df['mass'] == 0].sample(n=dfmass1000.shape[0], random_state=1)        #0 same size of dfmass1000
        dfmass1000=pd.concat([dfmass1000, dfmass0]).sample(frac=1).reset_index(drop=True)    #concatenating and shuffling
        dfmass1000=dfmass1000.drop('mass', axis=1)          

        #test
        dfmass1000test=df_originaltest.loc[df_originaltest['mass'] == i]
        dfmass0test=df_originaltest.loc[df_originaltest['mass'] == 0].sample(n=dfmass1000test.shape[0], random_state=1)
        dfmass1000test=pd.concat([dfmass1000test, dfmass0test]).sample(frac=1).reset_index(drop=True)
        dfmass1000test=dfmass1000test.drop('mass', axis=1)

        X_train=dfmass1000.drop(['label'], axis=1)
        y_train=dfmass1000.label

        X_test=dfmass1000test.drop(['label'], axis=1)
        y_test=dfmass1000test.label

        numbermodel=1

        
        grid,best_model,y_pred,y_pred_proba = model(X_train,y_train,X_test,numbermodel)#,W)
        print(best_model)

        sens,spec,acc,kappa,tn, fp, fn, tp=Scores(y_test,y_pred)
        print('accuracy', acc)
        print('sensitibity', sens)
        print('specifity', spec)
        print('kappa', kappa)
        print('tn', tn)
        print('fp', fp)
        print('fn', fn)
        print('tp', tp)



        d = {'Valor': best_model.feature_importances_, 'Nombres': X_train.columns}
        importancias = pd.DataFrame(data=d)
        importancias=importancias.sort_values(by=['Valor'], ascending=False)

        importancias.Nombres= importancias.Nombres.astype('category')
        importancias.Valor= importancias.Valor.astype('float')

        #g = ggplot(importancias, aes(x = 'Nombres', y = 'Valor'))+  geom_bar(colour="black", stat="identity") + theme(figure_size=(5, 7))+coord_flip()

        #g.save(filename = cwd +'MASS=' + str(i) + 'FR.png', height=5, width=5, units = 'in', dpi=1000)
        #print(g)
        #plt.clf() 



        #Roc curve construction

        fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
        auc = metrics.roc_auc_score(y_test, y_pred_proba)
        plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
        plt.legend(loc=4)
        plt.savefig(cwd+'MASS=' + str(i) + 'ROC.png')
        plt.show()
        plt.clf() 
        print('AUC', auc)

        df_metrics.accuracy[i]=acc
        df_metrics.sensitibity[i]=sens
        df_metrics.specifity[i]=spec
        df_metrics.kappa[i]=kappa
        df_metrics.auc[i]=auc

        print(X_train.shape)
        print(X_test.shape)

        #print(X_train.head(10))
        #print(X_test.head(10))
# Out:
# {0: 1, 1: 99}
# mass= 500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   55.2s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.5982142857142857
# sensitibity 0.7321428571428571
# specifity 0.4642857142857143
# kappa 0.1964285714285714
# tn 26
# fp 30
# fn 15
# tp 41
# AUC 0.6251594387755102
# (212, 27)
# (112, 27)
# mass= 750
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   53.4s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=350, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.7560975609756098
# sensitibity 0.8780487804878049
# specifity 0.6341463414634146
# kappa 0.5121951219512195
# tn 26
# fp 15
# fn 5
# tp 36
# AUC 0.8810232004759071
# (194, 27)
# (82, 27)
# mass= 1000
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   59.0s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.8404255319148937
# sensitibity 0.7872340425531915
# specifity 0.8936170212765957
# kappa 0.6808510638297872
# tn 42
# fp 5
# fn 10
# tp 37
# AUC 0.9119511090991399
# (172, 27)
# (94, 27)
# mass= 1250
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   56.1s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9242424242424242
# sensitibity 0.9696969696969697
# specifity 0.8787878787878788
# kappa 0.8484848484848485
# tn 29
# fp 4
# fn 1
# tp 32
# AUC 0.9775022956841138
# (230, 27)
# (66, 27)
# mass= 1500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   58.0s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9454545454545454
# sensitibity 0.9636363636363636
# specifity 0.9272727272727272
# kappa 0.8909090909090909
# tn 51
# fp 4
# fn 2
# tp 53
# AUC 0.9942148760330578
# (212, 27)
# (110, 27)
# {0: 1, 1: 90}
# mass= 500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.1min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.5714285714285714
# sensitibity 0.6785714285714286
# specifity 0.4642857142857143
# kappa 0.1428571428571429
# tn 26
# fp 30
# fn 18
# tp 38
# AUC 0.6170280612244898
# (212, 27)
# (112, 27)
# mass= 750
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   59.4s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=350, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.7560975609756098
# sensitibity 0.8780487804878049
# specifity 0.6341463414634146
# kappa 0.5121951219512195
# tn 26
# fp 15
# fn 5
# tp 36
# AUC 0.8860797144556811
# (194, 27)
# (82, 27)
# mass= 1000
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   54.4s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=350, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.8829787234042553
# sensitibity 0.8723404255319149
# specifity 0.8936170212765957
# kappa 0.7659574468085106
# tn 42
# fp 5
# fn 6
# tp 41
# AUC 0.9357175192394749
# (172, 27)
# (94, 27)
# mass= 1250
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   56.6s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9545454545454546
# sensitibity 1.0
# specifity 0.9090909090909091
# kappa 0.9090909090909091
# tn 30
# fp 3
# fn 0
# tp 33
# AUC 0.9761248852157943
# (230, 27)
# (66, 27)
# mass= 1500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   58.1s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9454545454545454
# sensitibity 0.9636363636363636
# specifity 0.9272727272727272
# kappa 0.8909090909090909
# tn 51
# fp 4
# fn 2
# tp 53
# AUC 0.9930578512396695
# (212, 27)
# (110, 27)
# {0: 1, 1: 67}
# mass= 500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.0min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.5446428571428571
# sensitibity 0.6785714285714286
# specifity 0.4107142857142857
# kappa 0.0892857142857143
# tn 23
# fp 33
# fn 18
# tp 38
# AUC 0.5988520408163267
# (212, 27)
# (112, 27)
# mass= 750
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.0min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.8048780487804879
# sensitibity 0.9024390243902439
# specifity 0.7073170731707317
# kappa 0.6097560975609756
# tn 29
# fp 12
# fn 4
# tp 37
# AUC 0.8905413444378346
# (194, 27)
# (82, 27)
# mass= 1000
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   57.2s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.8829787234042553
# sensitibity 0.8723404255319149
# specifity 0.8936170212765957
# kappa 0.7659574468085106
# tn 42
# fp 5
# fn 6
# tp 41
# AUC 0.934133091896786
# (172, 27)
# (94, 27)
# mass= 1250
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   56.8s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9393939393939394
# sensitibity 1.0
# specifity 0.8787878787878788
# kappa 0.8787878787878788
# tn 29
# fp 4
# fn 0
# tp 33
# AUC 0.9628099173553719
# (230, 27)
# (66, 27)
# mass= 1500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.0min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9545454545454546
# sensitibity 0.9636363636363636
# specifity 0.9454545454545454
# kappa 0.9090909090909091
# tn 52
# fp 3
# fn 2
# tp 53
# AUC 0.9927272727272728
# (212, 27)
# (110, 27)
# {0: 1, 1: 50}
# mass= 500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.0min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=350, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.5982142857142857
# sensitibity 0.75
# specifity 0.44642857142857145
# kappa 0.1964285714285714
# tn 25
# fp 31
# fn 14
# tp 42
# AUC 0.6264349489795918
# (212, 27)
# (112, 27)
# mass= 750
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   59.7s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.7560975609756098
# sensitibity 0.8536585365853658
# specifity 0.6585365853658537
# kappa 0.5121951219512195
# tn 27
# fp 14
# fn 6
# tp 35
# AUC 0.888459250446163
# (194, 27)
# (82, 27)
# mass= 1000
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   57.0s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.8723404255319149
# sensitibity 0.8723404255319149
# specifity 0.8723404255319149
# kappa 0.7446808510638299
# tn 41
# fp 6
# fn 6
# tp 41
# AUC 0.9465821638750567
# (172, 27)
# (94, 27)
# mass= 1250
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.0min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9090909090909091
# sensitibity 0.9393939393939394
# specifity 0.8787878787878788
# kappa 0.8181818181818181
# tn 29
# fp 4
# fn 2
# tp 31
# AUC 0.9586776859504132
# (230, 27)
# (66, 27)
# mass= 1500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   58.5s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9363636363636364
# sensitibity 0.9636363636363636
# specifity 0.9090909090909091
# kappa 0.8727272727272728
# tn 50
# fp 5
# fn 2
# tp 53
# AUC 0.9882644628099174
# (212, 27)
# (110, 27)
# {0: 1, 1: 34}
# mass= 500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.1min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=350, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.6071428571428571
# sensitibity 0.7321428571428571
# specifity 0.48214285714285715
# kappa 0.2142857142857143
# tn 27
# fp 29
# fn 15
# tp 41
# AUC 0.6221301020408163
# (212, 27)
# (112, 27)
# mass= 750
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.0min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=350, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.7682926829268293
# sensitibity 0.8780487804878049
# specifity 0.6585365853658537
# kappa 0.5365853658536586
# tn 27
# fp 14
# fn 5
# tp 36
# AUC 0.8866745984533017
# (194, 27)
# (82, 27)
# mass= 1000
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   57.1s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.8829787234042553
# sensitibity 0.8723404255319149
# specifity 0.8936170212765957
# kappa 0.7659574468085106
# tn 42
# fp 5
# fn 6
# tp 41
# AUC 0.9400181077410592
# (172, 27)
# (94, 27)
# mass= 1250
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   59.4s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9242424242424242
# sensitibity 0.9393939393939394
# specifity 0.9090909090909091
# kappa 0.8484848484848485
# tn 30
# fp 3
# fn 2
# tp 31
# AUC 0.9664830119375574
# (230, 27)
# (66, 27)
# mass= 1500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   54.4s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=350, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9545454545454546
# sensitibity 0.9636363636363636
# specifity 0.9454545454545454
# kappa 0.9090909090909091
# tn 52
# fp 3
# fn 2
# tp 53
# AUC 0.9943801652892562
# (212, 27)
# (110, 27)
# {0: 1, 1: 10}
# mass= 500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.0min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=350, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.5714285714285714
# sensitibity 0.6964285714285714
# specifity 0.44642857142857145
# kappa 0.1428571428571429
# tn 25
# fp 31
# fn 17
# tp 39
# AUC 0.6192602040816326
# (212, 27)
# (112, 27)
# mass= 750
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.0min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.7926829268292683
# sensitibity 0.8780487804878049
# specifity 0.7073170731707317
# kappa 0.5853658536585367
# tn 29
# fp 12
# fn 5
# tp 36
# AUC 0.8780487804878049
# (194, 27)
# (82, 27)
# mass= 1000
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   57.4s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.8829787234042553
# sensitibity 0.8723404255319149
# specifity 0.8936170212765957
# kappa 0.7659574468085106
# tn 42
# fp 5
# fn 6
# tp 41
# AUC 0.9359438660027162
# (172, 27)
# (94, 27)
# mass= 1250
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.1min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9242424242424242
# sensitibity 0.9696969696969697
# specifity 0.8787878787878788
# kappa 0.8484848484848485
# tn 29
# fp 4
# fn 1
# tp 32
# AUC 0.9660238751147843
# (230, 27)
# (66, 27)
# mass= 1500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   55.1s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=350, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9454545454545454
# sensitibity 0.9636363636363636
# specifity 0.9272727272727272
# kappa 0.8909090909090909
# tn 51
# fp 4
# fn 2
# tp 53
# AUC 0.9933884297520661
# (212, 27)
# (110, 27)
# {0: 1, 1: 1}
# mass= 500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  1.1min finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.5714285714285714
# sensitibity 0.6607142857142857
# specifity 0.48214285714285715
# kappa 0.1428571428571429
# tn 27
# fp 29
# fn 19
# tp 37
# AUC 0.5996492346938775
# (212, 27)
# (112, 27)
# mass= 750
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   57.6s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.7682926829268293
# sensitibity 0.8780487804878049
# specifity 0.6585365853658537
# kappa 0.5365853658536586
# tn 27
# fp 14
# fn 5
# tp 36
# AUC 0.8759666864961332
# (194, 27)
# (82, 27)
# mass= 1000
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   53.4s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.8829787234042553
# sensitibity 0.8936170212765957
# specifity 0.8723404255319149
# kappa 0.7659574468085106
# tn 41
# fp 6
# fn 5
# tp 42
# AUC 0.9404708012675418
# (172, 27)
# (94, 27)
# mass= 1250
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   58.4s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='log2',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9545454545454546
# sensitibity 1.0
# specifity 0.9090909090909091
# kappa 0.9090909090909091
# tn 30
# fp 3
# fn 0
# tp 33
# AUC 0.9742883379247016
# (230, 27)
# (66, 27)
# mass= 1500
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   57.5s finished
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 1},
#             criterion='entropy', max_depth=None, max_features='sqrt',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# accuracy 0.9545454545454546
# sensitibity 0.9636363636363636
# specifity 0.9454545454545454
# kappa 0.9090909090909091
# tn 52
# fp 3
# fn 2
# tp 53
# AUC 0.992396694214876
# (212, 27)
# (110, 27)

# %%
'''print(X_train.shape)
print(X_test.shape)
y_test.value_counts()'''
# Out:
# 'print(X_train.shape)\nprint(X_test.shape)\ny_test.value_counts()'

# %%
'''fig, ax = plt.subplots()
ax.plot(["500","750","1000","1250","1500"], df_metrics["accuracy"], label="accuracy")
ax.plot(["500","750","1000","1250","1500"], df_metrics["sensitibity"], label="sensitibity")
ax.plot(["500","750","1000","1250","1500"], df_metrics["specifity"], label="specifity")
ax.plot(["500","750","1000","1250","1500"], df_metrics["auc"], label="auc")
ax.plot(["500","750","1000","1250","1500"], df_metrics["kappa"], label="kappa")

ax.set_xlabel('mass')
ax.set_ylabel('Metric')
legend = ax.legend(fontsize='x-large')
plt.show()
plt.savefig(cwd+ 'metrics_comparation.png')'''
# Out:
# 'fig, ax = plt.subplots()\nax.plot(["500","750","1000","1250","1500"], df_metrics["accuracy"], label="accuracy")\nax.plot(["500","750","1000","1250","1500"], df_metrics["sensitibity"], label="sensitibity")\nax.plot(["500","750","1000","1250","1500"], df_metrics["specifity"], label="specifity")\nax.plot(["500","750","1000","1250","1500"], df_metrics["auc"], label="auc")\nax.plot(["500","750","1000","1250","1500"], df_metrics["kappa"], label="kappa")\n\nax.set_xlabel(\'mass\')\nax.set_ylabel(\'Metric\')\nlegend = ax.legend(fontsize=\'x-large\')\nplt.show()\nplt.savefig(cwd+ \'metrics_comparation.png\')'
